# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as stats
import csv
import datetime
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_csv('cfr.csv')
df.set_index('date')
df.columns
# Out:
# Index(['period t', 'date', 'item', 'quantity', 'day', 'deseasonlised ',
#        'Deaseasonlised (Dt)', 'seasonal', 'seasonal index', 'Unnamed: 9',
#        'Unnamed: 10', 'Moving average( 3 days )', 'Moving average( 6 days )',
#        'weighted moving average', 'exponential smoothing', 'Holt's model( L )',
#        'Holt's model ( T )', 'Holt's model ( Ft )', 'Winter's model ( L )',
#        'Winter's model ( T )', 'Winter's model ( S )', 'Winter's model ( F )',
#        'moving average 3d error', 'moving average 6d error',
#        'weighted average error', 'exponential smoothing error',
#        'holt's model error', 'winter's model error', 'Unnamed: 28',
#        'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
#        'Unnamed: 33'],
#       dtype='object')

# %%
df[['quantity','Moving average( 3 days )']].plot(figsize=(20,8))
plt.title('Chicken Fried Rice Moving Averages 3 days')
plt.axis('tight')
plt.grid(True)

# %%
df[['quantity','Moving average( 6 days )']].plot(figsize=(20,8))
plt.title('Chicken Fried Rice Moving Averages 6 days')
plt.axis('tight')
plt.grid(True)

# %%
df[['quantity','Deaseasonlised (Dt)']].plot(figsize=(20,8))
plt.grid(True)

# %%
df[['quantity','weighted moving average']].plot(figsize=(20,8))
plt.title('Chicken Fried Rice weighted Moving Averages 3 days')
plt.axis('tight')
plt.grid(True)

# %%
df[['quantity', 'exponential smoothing']].plot(figsize=(20,8))
plt.title('Chicken Fried Rice exponential smoothing')
plt.axis('tight')
plt.grid(True)

# %%
df[['quantity',"Holt's model ( Ft )"]].plot(figsize=(20,8))
plt.title('Chicken Fried Rice Holts model')
plt.axis('tight')
plt.grid(True)

# %%
df[['quantity',"Winter's model ( F )"]].plot(figsize=(20,8))
plt.title('Chicken Fried Rice Winters model')
plt.axis('tight')
plt.grid(True)
